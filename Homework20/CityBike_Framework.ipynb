# %%
# Dependencies
import numpy as np
import pandas as pd
import os

# %%
# Create dataframe from csv file
csvpath = os.path.join('201701-citibike-tripdata.csv')
citybike71_df = pd.read_csv(csvpath)
citybike71_df.head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
citybike71_df['Year'] = pd.DatetimeIndex(citybike71_df['Start Time']).year

# %%
citybike71_df.head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
citybike71_df['Month'] = pd.DatetimeIndex(citybike71_df['Start Time']).month
citybike71_df.head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
csvpath = os.path.join('201702-citibike-tripdata.csv')
citybike72_df = pd.read_csv(csvpath)
citybike72_df['Year'] = pd.DatetimeIndex(citybike72_df['Start Time']).year
citybike72_df['Month'] = pd.DatetimeIndex(citybike72_df['Start Time']).month
citybike72_df.head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1087  2017-02-01 00:00:13  2017-02-01 00:18:20               345
# 1            704  2017-02-01 00:00:31  2017-02-01 00:12:15              3295
# 2            212  2017-02-01 00:00:34  2017-02-01 00:04:06               336
# 3           1140  2017-02-01 00:00:44  2017-02-01 00:19:44               484
# 4            320  2017-02-01 00:00:42  2017-02-01 00:06:02               490
#
#             Start Station Name  Start Station Latitude  \
# 0              W 13 St & 6 Ave               40.736494
# 1     Central Park W & W 96 St               40.791270
# 2  Sullivan St & Washington Sq               40.730477
# 3              W 44 St & 5 Ave               40.755003
# 4              8 Ave & W 33 St               40.751551
#
#    Start Station Longitude  End Station ID          End Station Name  \
# 0               -73.997044             305           E 58 St & 3 Ave
# ...

# %%
csvpath = os.path.join('201703-citibike-tripdata.csv')
citybike73_df = pd.read_csv(csvpath)
citybike73_df['Year'] = pd.DatetimeIndex(citybike73_df['Start Time']).year
citybike73_df['Month'] = pd.DatetimeIndex(citybike73_df['Start Time']).month
citybike73_df.head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1893  2017-03-01 00:00:32  2017-03-01 00:32:06              2009
# 1            223  2017-03-01 00:01:09  2017-03-01 00:04:53               127
# 2           1665  2017-03-01 00:01:27  2017-03-01 00:29:12               174
# 3            100  2017-03-01 00:01:29  2017-03-01 00:03:10               316
# 4           1229  2017-03-01 00:01:33  2017-03-01 00:22:02               536
#
#          Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Catherine St & Monroe St               40.711174               -73.996826
# 1     Barrow St & Hudson St               40.731724               -74.006744
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3    Fulton St & William St               40.709560               -74.006536
# 4           1 Ave & E 30 St               40.741444               -73.975361
#
# ...

# %%
csvpath = os.path.join('201704-citibike-tripdata.csv')
citybike74_df = pd.read_csv(csvpath)
citybike74_df['Year'] = pd.DatetimeIndex(citybike74_df['starttime']).year
citybike74_df['Month'] = pd.DatetimeIndex(citybike74_df['starttime']).month
citybike74_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           195  2017-04-01 00:00:58  2017-04-01 00:04:14               217
# 1           585  2017-04-01 00:01:54  2017-04-01 00:11:40               490
# 2           665  2017-04-01 00:01:56  2017-04-01 00:13:01               504
# 3           262  2017-04-01 00:02:24  2017-04-01 00:06:47               445
# 4           134  2017-04-01 00:02:36  2017-04-01 00:04:50              3423
#
#                 start station name  start station latitude  \
# 0                    Old Fulton St               40.702772
# 1                  8 Ave & W 33 St               40.751551
# 2                  1 Ave & E 16 St               40.732219
# 3               E 10 St & Avenue A               40.727408
# 4  West Drive & Prospect Park West               40.661063
#
#    start station longitude  end station id           end station name  \
# 0               -73.993836             430           York St & Jay St
# ...

# %%
csvpath = os.path.join('201705-citibike-tripdata.csv')
citybike75_df = pd.read_csv(csvpath)
citybike75_df['Year'] = pd.DatetimeIndex(citybike75_df['starttime']).year
citybike75_df['Month'] = pd.DatetimeIndex(citybike75_df['starttime']).month
citybike75_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           254  2017-05-01 00:00:13  2017-05-01 00:04:27               511
# 1           248  2017-05-01 00:00:19  2017-05-01 00:04:28               511
# 2          1120  2017-05-01 00:00:19  2017-05-01 00:19:00               242
# 3           212  2017-05-01 00:00:24  2017-05-01 00:03:56               168
# 4           686  2017-05-01 00:00:29  2017-05-01 00:11:55               494
#
#            start station name  start station latitude  \
# 0          E 14 St & Avenue B               40.729387
# 1          E 14 St & Avenue B               40.729387
# 2  Carlton Ave & Flushing Ave               40.697787
# 3             W 18 St & 6 Ave               40.739713
# 4             W 26 St & 8 Ave               40.747348
#
#    start station longitude  end station id          end station name  \
# 0               -73.977724             394         E 9 St & Avenue C
# ...

# %%
csvpath = os.path.join('201706-citibike-tripdata.csv')
citybike76_df = pd.read_csv(csvpath)
citybike76_df['Year'] = pd.DatetimeIndex(citybike76_df['starttime']).year
citybike76_df['Month'] = pd.DatetimeIndex(citybike76_df['starttime']).month
citybike76_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1397  2017-06-01 00:00:02  2017-06-01 00:23:19               515
# 1          1103  2017-06-01 00:00:13  2017-06-01 00:18:37               488
# 2          1810  2017-06-01 00:00:20  2017-06-01 00:30:31               461
# 3          1760  2017-06-01 00:00:24  2017-06-01 00:29:45              2009
# 4          2165  2017-06-01 00:00:33  2017-06-01 00:36:38               360
#
#          start station name  start station latitude  start station longitude  \
# 0          W 43 St & 10 Ave               40.760094               -73.994618
# 1           W 39 St & 9 Ave               40.756458               -73.993722
# 2           E 20 St & 2 Ave               40.735877               -73.982050
# 3  Catherine St & Monroe St               40.711174               -73.996826
# 4      William St & Pine St               40.707179               -74.008873
#
# ...

# %%
csvpath = os.path.join('201707-citibike-tripdata.csv')
citybike77_df = pd.read_csv(csvpath)
citybike77_df['Year'] = pd.DatetimeIndex(citybike77_df['starttime']).year
citybike77_df['Month'] = pd.DatetimeIndex(citybike77_df['starttime']).month
citybike77_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# ...

# %%
csvpath = os.path.join('201708-citibike-tripdata.csv')
citybike78_df = pd.read_csv(csvpath)
citybike78_df['Year'] = pd.DatetimeIndex(citybike78_df['starttime']).year
citybike78_df['Month'] = pd.DatetimeIndex(citybike78_df['starttime']).month
citybike78_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          2110  2017-08-01 00:00:00  2017-08-01 00:35:11               470
# 1           160  2017-08-01 00:00:10  2017-08-01 00:02:51               348
# 2          1644  2017-08-01 00:00:17  2017-08-01 00:27:41              3165
# 3           323  2017-08-01 00:00:27  2017-08-01 00:05:51               389
# 4           109  2017-08-01 00:00:41  2017-08-01 00:02:31              3145
#
#             start station name  start station latitude  \
# 0              W 20 St & 8 Ave               40.743453
# 1       W Broadway & Spring St               40.724910
# 2  Central Park West & W 72 St               40.775794
# 3          Broadway & Berry St               40.710446
# 4           E 84 St & Park Ave               40.778627
#
#    start station longitude  end station id              end station name  \
# 0               -74.000040            3289       W 90 St & Amsterdam Ave
# ...

# %%
csvpath = os.path.join('201709-citibike-tripdata.csv')
citybike79_df = pd.read_csv(csvpath)
citybike79_df['Year'] = pd.DatetimeIndex(citybike79_df['starttime']).year
citybike79_df['Month'] = pd.DatetimeIndex(citybike79_df['starttime']).month
citybike79_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           362  2017-09-01 00:00:17  2017-09-01 00:06:19              3331
# 1           188  2017-09-01 00:00:21  2017-09-01 00:03:30              3101
# 2           305  2017-09-01 00:00:25  2017-09-01 00:05:30              3140
# 3           223  2017-09-01 00:00:52  2017-09-01 00:04:36               236
# 4           758  2017-09-01 00:01:01  2017-09-01 00:13:40              3427
#
#          start station name  start station latitude  start station longitude  \
# 0   Riverside Dr & W 104 St               40.801343               -73.971146
# 1     N 12 St & Bedford Ave               40.720798               -73.954847
# 2           1 Ave & E 78 St               40.771404               -73.953517
# 3       St Marks Pl & 2 Ave               40.728419               -73.987140
# 4  Lafayette St & Jersey St               40.724305               -73.996010
#
# ...

# %%
csvpath = os.path.join('201710-citibike-tripdata.csv')
citybike710_df = pd.read_csv(csvpath)
citybike710_df['Year'] = pd.DatetimeIndex(citybike710_df['starttime']).year
citybike710_df['Month'] = pd.DatetimeIndex(citybike710_df['starttime']).month
citybike710_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           457  2017-10-01 00:00:00  2017-10-01 00:07:38               479
# 1          6462  2017-10-01 00:00:20  2017-10-01 01:48:03               279
# 2           761  2017-10-01 00:00:27  2017-10-01 00:13:09               504
# 3          1193  2017-10-01 00:00:29  2017-10-01 00:20:22              3236
# 4          2772  2017-10-01 00:00:32  2017-10-01 00:46:44              2006
#
#        start station name  start station latitude  start station longitude  \
# 0         9 Ave & W 45 St               40.760193               -73.991255
# 1    Peck Slip & Front St               40.707873               -74.001670
# 2         1 Ave & E 16 St               40.732219               -73.981656
# 3      W 42 St & Dyer Ave               40.758985               -73.993800
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
# ...

# %%
csvpath = os.path.join('201711-citibike-tripdata.csv')
citybike711_df = pd.read_csv(csvpath)
citybike711_df['Year'] = pd.DatetimeIndex(citybike711_df['starttime']).year
citybike711_df['Month'] = pd.DatetimeIndex(citybike711_df['starttime']).month
citybike711_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           297  2017-11-01 00:00:01  2017-11-01 00:04:59               418
# 1           269  2017-11-01 00:00:01  2017-11-01 00:04:30              3556
# 2           285  2017-11-01 00:00:04  2017-11-01 00:04:50               275
# 3           478  2017-11-01 00:00:13  2017-11-01 00:08:11              3545
# 4           574  2017-11-01 00:00:20  2017-11-01 00:09:54               458
#
#             start station name  start station latitude  \
# 0           Front St & Gold St               40.702240
# 1               24 St & 41 Ave               40.752709
# 2  Washington Ave & Greene Ave               40.686501
# 3          Broadway & W 122 St               40.812056
# 4             11 Ave & W 27 St               40.751396
#
#    start station longitude  end station id          end station name  \
# 0               -73.982578             414   Pearl St & Anchorage Pl
# ...

# %%
csvpath = os.path.join('201712-citibike-tripdata.csv')
citybike712_df = pd.read_csv(csvpath)
citybike712_df['Year'] = pd.DatetimeIndex(citybike712_df['starttime']).year
citybike712_df['Month'] = pd.DatetimeIndex(citybike712_df['starttime']).month
citybike712_df.head(5)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           256  2017-12-01 00:00:00  2017-12-01 00:04:17               324
# 1           325  2017-12-01 00:00:17  2017-12-01 00:05:43               470
# 2           967  2017-12-01 00:00:19  2017-12-01 00:16:26               347
# 3           125  2017-12-01 00:00:20  2017-12-01 00:02:26              3077
# 4           451  2017-12-01 00:00:28  2017-12-01 00:08:00               368
#
#             start station name  start station latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1              W 20 St & 8 Ave               40.743453
# 2  Greenwich St & W Houston St               40.728846
# 3         Stagg St & Union Ave               40.708771
# 4           Carmine St & 6 Ave               40.730386
#
#    start station longitude  end station id        end station name  \
# 0               -73.981013             262         Washington Park
# ...

# %%
citybikeDataUnion = citybike74_df.append(citybike75_df).append(citybike76_df).append(citybike77_df).append(citybike78_df).append(citybike79_df).append(citybike710_df).append(citybike711_df).append(citybike712_df)

# %%
citybikeDataU = citybike71_df.append(citybike72_df).append(citybike73_df)

# %%
citybikeDataU.head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
citybikeDataUnion.rename(columns={ 'tripduration' : 'Trip Duration', 'starttime': 'Start Time', 'stoptime': 'Stop Time', 'start station id': 'Start Station ID', 'start station name': 'Start Station Name', 'start station latitude': 'Start Station Latitude', 'start station longitude': 'Start Station Longitude', 'end station id': 'End Station ID', 'end station name': 'End Station Name', 'end station latitude': 'End Station Latitude', 'end station longitude': 'End Station Longitude'
 , 'bikeid': 'Bike ID', 'usertype': 'User Type', 'birth year': 'Birth Year', 'gender': 'Gender'}, inplace=True)

# %%
citybikeDataUnion.head(5)
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            195  2017-04-01 00:00:58  2017-04-01 00:04:14               217
# 1            585  2017-04-01 00:01:54  2017-04-01 00:11:40               490
# 2            665  2017-04-01 00:01:56  2017-04-01 00:13:01               504
# 3            262  2017-04-01 00:02:24  2017-04-01 00:06:47               445
# 4            134  2017-04-01 00:02:36  2017-04-01 00:04:50              3423
#
#                 Start Station Name  Start Station Latitude  \
# 0                    Old Fulton St               40.702772
# 1                  8 Ave & W 33 St               40.751551
# 2                  1 Ave & E 16 St               40.732219
# 3               E 10 St & Avenue A               40.727408
# 4  West Drive & Prospect Park West               40.661063
#
#    Start Station Longitude  End Station ID           End Station Name  \
# 0               -73.993836             430           York St & Jay St
# ...

# %%
cityBikeData = citybikeDataU.append(citybikeDataUnion)

# %%
cityBikeData.to_csv('cityBikeData.csv', sep=',', index=False, encoding='utf-8')
